# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}&q="

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print(f"City {city} not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | saldanha
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | lamu
# Processing Record 5 of Set 1 | barentsburg
# City barentsburg not found. Skipping...
# Processing Record 6 of Set 1 | belushya guba
# City belushya guba not found. Skipping...
# Processing Record 7 of Set 1 | longonjo
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | taolanaro
# City taolanaro not found. Skipping...
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | santa rosa
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | broome
# Processing Record 21 of Set 1 | mananjary
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | sisimiut
# Processing Record 25 of Set 1 | kamenskoye
# City kamenskoye not found. Skipping...
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | nyurba
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | flinders
# Processing Record 31 of Set 1 | huarmey
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | amparai
# City amparai not found. Skipping...
# Processing Record 35 of Set 1 | provideniya
# Processing Record 36 of Set 1 | aksarayskiy
# Processing Record 37 of Set 1 | warah
# Processing Record 38 of Set 1 | stepnyak
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | brae
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | dingle
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | aklavik
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | rundu
# Processing Record 48 of Set 1 | rodez
# Processing Record 49 of Set 1 | cairns
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | vostok
# Processing Record 3 of Set 2 | alta floresta
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | bay city
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | batetskiy
# Processing Record 8 of Set 2 | carlagan
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | codrington
# Processing Record 11 of Set 2 | pochutla
# Processing Record 12 of Set 2 | norman wells
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | bubaque
# Processing Record 15 of Set 2 | kempsey
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | cidreira
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | okhotsk
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | channagiri
# Processing Record 23 of Set 2 | ranong
# Processing Record 24 of Set 2 | kitui
# Processing Record 25 of Set 2 | castro
# Processing Record 26 of Set 2 | grand river south east
# City grand river south east not found. Skipping...
# Processing Record 27 of Set 2 | gazli
# Processing Record 28 of Set 2 | jutai
# Processing Record 29 of Set 2 | high river
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | vaitupu
# City vaitupu not found. Skipping...
# Processing Record 32 of Set 2 | touros
# Processing Record 33 of Set 2 | illoqqortoormiut
# City illoqqortoormiut not found. Skipping...
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | ahipara
# Processing Record 36 of Set 2 | chavakkad
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | kurumkan
# Processing Record 39 of Set 2 | coquimbo
# Processing Record 40 of Set 2 | tuatapere
# Processing Record 41 of Set 2 | tual
# Processing Record 42 of Set 2 | talnakh
# Processing Record 43 of Set 2 | sept-iles
# Processing Record 44 of Set 2 | cherskiy
# Processing Record 45 of Set 2 | tabiauea
# City tabiauea not found. Skipping...
# Processing Record 46 of Set 2 | cap malheureux
# Processing Record 47 of Set 2 | umzimvubu
# City umzimvubu not found. Skipping...
# Processing Record 48 of Set 2 | safonovo
# Processing Record 49 of Set 2 | albany
# Processing Record 50 of Set 2 | ust-kuyga
# Processing Record 1 of Set 3 | galesong
# Processing Record 2 of Set 3 | kisangani
# Processing Record 3 of Set 3 | staunton
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | santarem
# Processing Record 6 of Set 3 | fortuna
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | amderma
# City amderma not found. Skipping...
# Processing Record 9 of Set 3 | simao
# Processing Record 10 of Set 3 | ostersund
# Processing Record 11 of Set 3 | adlay
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | inhambane
# Processing Record 14 of Set 3 | taree
# Processing Record 15 of Set 3 | sur
# Processing Record 16 of Set 3 | kutum
# Processing Record 17 of Set 3 | kaitangata
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | lazaro cardenas
# Processing Record 20 of Set 3 | praia
# Processing Record 21 of Set 3 | port lincoln
# Processing Record 22 of Set 3 | te anau
# Processing Record 23 of Set 3 | adrar
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | shimoda
# Processing Record 26 of Set 3 | bulgan
# Processing Record 27 of Set 3 | pervomayskoye
# Processing Record 28 of Set 3 | cravo norte
# Processing Record 29 of Set 3 | kizukuri
# Processing Record 30 of Set 3 | port augusta
# Processing Record 31 of Set 3 | sorong
# Processing Record 32 of Set 3 | bandiagara
# Processing Record 33 of Set 3 | ust-nera
# Processing Record 34 of Set 3 | saint-augustin
# Processing Record 35 of Set 3 | uporovo
# Processing Record 36 of Set 3 | hasaki
# Processing Record 37 of Set 3 | hanzhong
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | klaksvik
# Processing Record 40 of Set 3 | ludza
# Processing Record 41 of Set 3 | cape town
# Processing Record 42 of Set 3 | nove hrady
# Processing Record 43 of Set 3 | torrington
# Processing Record 44 of Set 3 | mys shmidta
# City mys shmidta not found. Skipping...
# Processing Record 45 of Set 3 | lerwick
# Processing Record 46 of Set 3 | nouadhibou
# Processing Record 47 of Set 3 | huilong
# Processing Record 48 of Set 3 | nemuro
# Processing Record 49 of Set 3 | lolua
# City lolua not found. Skipping...
# Processing Record 50 of Set 3 | mar del plata
# Processing Record 1 of Set 4 | iralaya
# Processing Record 2 of Set 4 | plouzane
# Processing Record 3 of Set 4 | neiafu
# Processing Record 4 of Set 4 | mehamn
# Processing Record 5 of Set 4 | naspur
# Processing Record 6 of Set 4 | ijaki
# City ijaki not found. Skipping...
# Processing Record 7 of Set 4 | wasilla
# Processing Record 8 of Set 4 | saryshagan
# City saryshagan not found. Skipping...
# Processing Record 9 of Set 4 | at-bashi
# Processing Record 10 of Set 4 | svetlogorsk
# Processing Record 11 of Set 4 | jalu
# Processing Record 12 of Set 4 | jacareacanga
# Processing Record 13 of Set 4 | laguna
# Processing Record 14 of Set 4 | severo-kurilsk
# Processing Record 15 of Set 4 | bethel
# Processing Record 16 of Set 4 | gandorhun
# Processing Record 17 of Set 4 | tasiilaq
# Processing Record 18 of Set 4 | attawapiskat
# City attawapiskat not found. Skipping...
# Processing Record 19 of Set 4 | karaman
# Processing Record 20 of Set 4 | faya
# Processing Record 21 of Set 4 | aasiaat
# Processing Record 22 of Set 4 | cookshire
# City cookshire not found. Skipping...
# Processing Record 23 of Set 4 | barrow
# Processing Record 24 of Set 4 | nizhniy ufaley
# Processing Record 25 of Set 4 | saskylakh
# Processing Record 26 of Set 4 | riverton
# Processing Record 27 of Set 4 | lebu
# Processing Record 28 of Set 4 | neuquen
# Processing Record 29 of Set 4 | arrecife
# Processing Record 30 of Set 4 | karaul
# City karaul not found. Skipping...
# Processing Record 31 of Set 4 | faanui
# Processing Record 32 of Set 4 | malatya
# Processing Record 33 of Set 4 | solnechnyy
# Processing Record 34 of Set 4 | naftah
# City naftah not found. Skipping...
# Processing Record 35 of Set 4 | ostrovnoy
# Processing Record 36 of Set 4 | simpang
# Processing Record 37 of Set 4 | nanortalik
# Processing Record 38 of Set 4 | victoria
# Processing Record 39 of Set 4 | careiro da varzea
# Processing Record 40 of Set 4 | xiongshi
# City xiongshi not found. Skipping...
# Processing Record 41 of Set 4 | rafsanjan
# Processing Record 42 of Set 4 | sentyabrskiy
# City sentyabrskiy not found. Skipping...
# Processing Record 43 of Set 4 | alofi
# Processing Record 44 of Set 4 | saint george
# Processing Record 45 of Set 4 | grenaa
# Processing Record 46 of Set 4 | abbeville
# Processing Record 47 of Set 4 | kasaragod
# Processing Record 48 of Set 4 | ous
# Processing Record 49 of Set 4 | sistranda
# Processing Record 50 of Set 4 | de aar
# Processing Record 1 of Set 5 | virden
# Processing Record 2 of Set 5 | torbay
# Processing Record 3 of Set 5 | hamilton
# Processing Record 4 of Set 5 | kapoeta
# Processing Record 5 of Set 5 | havre-saint-pierre
# Processing Record 6 of Set 5 | tsihombe
# City tsihombe not found. Skipping...
# Processing Record 7 of Set 5 | guilin
# Processing Record 8 of Set 5 | rio grande
# Processing Record 9 of Set 5 | durango
# Processing Record 10 of Set 5 | krasnoselkup
# Processing Record 11 of Set 5 | samarai
# Processing Record 12 of Set 5 | katsuura
# Processing Record 13 of Set 5 | lianran
# Processing Record 14 of Set 5 | cabo san lucas
# Processing Record 15 of Set 5 | pontian kecil
# Processing Record 16 of Set 5 | lima
# Processing Record 17 of Set 5 | bossangoa
# Processing Record 18 of Set 5 | guerrero negro
# Processing Record 19 of Set 5 | bandarbeyla
# Processing Record 20 of Set 5 | mumbwa
# Processing Record 21 of Set 5 | wesselsbron
# Processing Record 22 of Set 5 | tigil
# Processing Record 23 of Set 5 | mana
# Processing Record 24 of Set 5 | hualmay
# Processing Record 25 of Set 5 | kindersley
# Processing Record 26 of Set 5 | chuy
# Processing Record 27 of Set 5 | gainesville
# Processing Record 28 of Set 5 | tabarqah
# City tabarqah not found. Skipping...
# Processing Record 29 of Set 5 | zapolyarnyy
# Processing Record 30 of Set 5 | lalomanu
# City lalomanu not found. Skipping...
# Processing Record 31 of Set 5 | monrovia
# Processing Record 32 of Set 5 | bathsheba
# Processing Record 33 of Set 5 | meyungs
# City meyungs not found. Skipping...
# Processing Record 34 of Set 5 | meadow lake
# Processing Record 35 of Set 5 | svidnik
# Processing Record 36 of Set 5 | ulaangom
# Processing Record 37 of Set 5 | chokurdakh
# Processing Record 38 of Set 5 | gao
# Processing Record 39 of Set 5 | inverell
# Processing Record 40 of Set 5 | resistencia
# Processing Record 41 of Set 5 | manjacaze
# Processing Record 42 of Set 5 | yanan
# City yanan not found. Skipping...
# Processing Record 43 of Set 5 | alihe
# Processing Record 44 of Set 5 | vao
# Processing Record 45 of Set 5 | quatre cocos
# Processing Record 46 of Set 5 | geraldton
# Processing Record 47 of Set 5 | san policarpo
# Processing Record 48 of Set 5 | myitkyina
# Processing Record 49 of Set 5 | tarudant
# City tarudant not found. Skipping...
# Processing Record 50 of Set 5 | ketchikan
# Processing Record 1 of Set 6 | ondorhaan
# City ondorhaan not found. Skipping...
# Processing Record 2 of Set 6 | columbus
# Processing Record 3 of Set 6 | jijiga
# Processing Record 4 of Set 6 | palmerston
# Processing Record 5 of Set 6 | dunedin
# Processing Record 6 of Set 6 | olafsvik
# Processing Record 7 of Set 6 | bengkulu
# Processing Record 8 of Set 6 | nha trang
# Processing Record 9 of Set 6 | portland
# Processing Record 10 of Set 6 | itarema
# Processing Record 11 of Set 6 | beaune
# Processing Record 12 of Set 6 | inderborskiy
# City inderborskiy not found. Skipping...
# Processing Record 13 of Set 6 | kyren
# Processing Record 14 of Set 6 | dvinskoy
# Processing Record 15 of Set 6 | pacific grove
# Processing Record 16 of Set 6 | tura
# Processing Record 17 of Set 6 | nizhneyansk
# City nizhneyansk not found. Skipping...
# Processing Record 18 of Set 6 | shelburne
# Processing Record 19 of Set 6 | oruro
# Processing Record 20 of Set 6 | iquitos
# Processing Record 21 of Set 6 | general roca
# Processing Record 22 of Set 6 | kaeo
# Processing Record 23 of Set 6 | luderitz
# Processing Record 24 of Set 6 | tripoli
# Processing Record 25 of Set 6 | yar-sale
# Processing Record 26 of Set 6 | tabou
# Processing Record 27 of Set 6 | gamba
# Processing Record 28 of Set 6 | faridan
# City faridan not found. Skipping...
# Processing Record 29 of Set 6 | banda aceh
# Processing Record 30 of Set 6 | bria
# Processing Record 31 of Set 6 | leningradskiy
# Processing Record 32 of Set 6 | aswan
# Processing Record 33 of Set 6 | natal
# Processing Record 34 of Set 6 | auki
# Processing Record 35 of Set 6 | tilichiki
# Processing Record 36 of Set 6 | louiseville
# Processing Record 37 of Set 6 | tarboro
# Processing Record 38 of Set 6 | mitsamiouli
# Processing Record 39 of Set 6 | upington
# Processing Record 40 of Set 6 | port blair
# Processing Record 41 of Set 6 | sao paulo de olivenca
# Processing Record 42 of Set 6 | tubruq
# City tubruq not found. Skipping...
# Processing Record 43 of Set 6 | dingli
# Processing Record 44 of Set 6 | ambon
# Processing Record 45 of Set 6 | misratah
# Processing Record 46 of Set 6 | kalmunai
# Processing Record 47 of Set 6 | half moon bay
# Processing Record 48 of Set 6 | sao joao da barra
# Processing Record 49 of Set 6 | jarjis
# City jarjis not found. Skipping...
# Processing Record 50 of Set 6 | tulun
# Processing Record 1 of Set 7 | ryotsu
# Processing Record 2 of Set 7 | sao sepe
# Processing Record 3 of Set 7 | kokopo
# Processing Record 4 of Set 7 | pareora
# Processing Record 5 of Set 7 | yerbogachen
# Processing Record 6 of Set 7 | mahuva
# Processing Record 7 of Set 7 | sotouboua
# Processing Record 8 of Set 7 | puro
# Processing Record 9 of Set 7 | rawson
# Processing Record 10 of Set 7 | honningsvag
# Processing Record 11 of Set 7 | bilibino
# Processing Record 12 of Set 7 | palabuhanratu
# City palabuhanratu not found. Skipping...
# Processing Record 13 of Set 7 | beringovskiy
# Processing Record 14 of Set 7 | presidencia roque saenz pena
# Processing Record 15 of Set 7 | lavrentiya
# Processing Record 16 of Set 7 | bintulu
# Processing Record 17 of Set 7 | taoudenni
# Processing Record 18 of Set 7 | ugoofaaru
# Processing Record 19 of Set 7 | nyimba
# Processing Record 20 of Set 7 | sibolga
# Processing Record 21 of Set 7 | hovd
# Processing Record 22 of Set 7 | paraibano
# Processing Record 23 of Set 7 | bambous virieux
# Processing Record 24 of Set 7 | padang
# Processing Record 25 of Set 7 | ikom
# Processing Record 26 of Set 7 | los llanos de aridane
# Processing Record 27 of Set 7 | tadine
# Processing Record 28 of Set 7 | ambilobe
# Processing Record 29 of Set 7 | evensk
# Processing Record 30 of Set 7 | henties bay
# Processing Record 31 of Set 7 | zhigansk
# Processing Record 32 of Set 7 | mao
# Processing Record 33 of Set 7 | homer
# Processing Record 34 of Set 7 | yalutorovsk
# Processing Record 35 of Set 7 | pinawa
# Processing Record 36 of Set 7 | yialos
# City yialos not found. Skipping...
# Processing Record 37 of Set 7 | skalistyy
# City skalistyy not found. Skipping...
# Processing Record 38 of Set 7 | lakes entrance
# Processing Record 39 of Set 7 | viedma
# Processing Record 40 of Set 7 | la primavera
# Processing Record 41 of Set 7 | halalo
# City halalo not found. Skipping...
# Processing Record 42 of Set 7 | perelyub
# Processing Record 43 of Set 7 | kalga
# Processing Record 44 of Set 7 | manzil tamim
# City manzil tamim not found. Skipping...
# Processing Record 45 of Set 7 | ashqelon
# Processing Record 46 of Set 7 | wagar
# Processing Record 47 of Set 7 | korla
# Processing Record 48 of Set 7 | batagay-alyta
# Processing Record 49 of Set 7 | panalingaan
# Processing Record 50 of Set 7 | kudahuvadhoo
# Processing Record 1 of Set 8 | ponta do sol
# Processing Record 2 of Set 8 | tororo
# Processing Record 3 of Set 8 | sharanga
# Processing Record 4 of Set 8 | de-kastri
# Processing Record 5 of Set 8 | sao gabriel da cachoeira
# Processing Record 6 of Set 8 | kahului
# Processing Record 7 of Set 8 | chom bung
# City chom bung not found. Skipping...
# Processing Record 8 of Set 8 | eyl
# Processing Record 9 of Set 8 | monzon
# Processing Record 10 of Set 8 | adelaide
# Processing Record 11 of Set 8 | khoy
# Processing Record 12 of Set 8 | dubasari
# Processing Record 13 of Set 8 | strai
# Processing Record 14 of Set 8 | grand-santi
# Processing Record 15 of Set 8 | riberalta
# Processing Record 16 of Set 8 | viligili
# City viligili not found. Skipping...
# Processing Record 17 of Set 8 | beloha
# Processing Record 18 of Set 8 | batagay
# Processing Record 19 of Set 8 | emerald
# Processing Record 20 of Set 8 | vila franca do campo
# Processing Record 21 of Set 8 | chapais
# Processing Record 22 of Set 8 | sakakah
# Processing Record 23 of Set 8 | namatanai
# Processing Record 24 of Set 8 | camacha
# Processing Record 25 of Set 8 | asilah
# Processing Record 26 of Set 8 | evans
# Processing Record 27 of Set 8 | pemangkat
# Processing Record 28 of Set 8 | saint-joseph
# Processing Record 29 of Set 8 | plettenberg bay
# Processing Record 30 of Set 8 | port hardy
# Processing Record 31 of Set 8 | salalah
# Processing Record 32 of Set 8 | tobermory
# Processing Record 33 of Set 8 | jaru
# Processing Record 34 of Set 8 | guerrero
# Processing Record 35 of Set 8 | tondano
# Processing Record 36 of Set 8 | dakar
# Processing Record 37 of Set 8 | grindavik
# Processing Record 38 of Set 8 | alotau
# City alotau not found. Skipping...
# Processing Record 39 of Set 8 | fort abbas
# Processing Record 40 of Set 8 | ribeira grande
# Processing Record 41 of Set 8 | jalalabad
# Processing Record 42 of Set 8 | zabol
# Processing Record 43 of Set 8 | barbar
# City barbar not found. Skipping...
# Processing Record 44 of Set 8 | samusu
# City samusu not found. Skipping...
# Processing Record 45 of Set 8 | virginia beach
# Processing Record 46 of Set 8 | tumannyy
# City tumannyy not found. Skipping...
# Processing Record 47 of Set 8 | dicabisagan
# Processing Record 48 of Set 8 | lafiagi
# Processing Record 49 of Set 8 | tahta
# Processing Record 50 of Set 8 | rocha
# Processing Record 1 of Set 9 | puerto ayacucho
# Processing Record 2 of Set 9 | quzhou
# Processing Record 3 of Set 9 | sandi
# Processing Record 4 of Set 9 | westport
# Processing Record 5 of Set 9 | lata
# Processing Record 6 of Set 9 | marzuq
# Processing Record 7 of Set 9 | elbistan
# Processing Record 8 of Set 9 | mahanoro
# Processing Record 9 of Set 9 | smithers
# Processing Record 10 of Set 9 | pecos
# Processing Record 11 of Set 9 | yakeshi
# Processing Record 12 of Set 9 | utete
# Processing Record 13 of Set 9 | san cristobal
# Processing Record 14 of Set 9 | srednekolymsk
# Processing Record 15 of Set 9 | lorengau
# Processing Record 16 of Set 9 | port hedland
# Processing Record 17 of Set 9 | freetown
# Processing Record 18 of Set 9 | netrakona
# Processing Record 19 of Set 9 | ak-dovurak
# Processing Record 20 of Set 9 | vestmanna
# Processing Record 21 of Set 9 | san patricio
# Processing Record 22 of Set 9 | lichinga
# Processing Record 23 of Set 9 | zeya
# Processing Record 24 of Set 9 | ancud
# Processing Record 25 of Set 9 | esperance
# Processing Record 26 of Set 9 | carroll
# Processing Record 27 of Set 9 | kodinsk
# Processing Record 28 of Set 9 | galveston
# Processing Record 29 of Set 9 | kourou
# Processing Record 30 of Set 9 | gat
# Processing Record 31 of Set 9 | airai
# Processing Record 32 of Set 9 | iquique
# Processing Record 33 of Set 9 | beira
# Processing Record 34 of Set 9 | erenhot
# Processing Record 35 of Set 9 | cururupu
# Processing Record 36 of Set 9 | mustafabad
# Processing Record 37 of Set 9 | dudinka
# Processing Record 38 of Set 9 | port pirie
# Processing Record 39 of Set 9 | mantua
# Processing Record 40 of Set 9 | sangin
# Processing Record 41 of Set 9 | xining
# Processing Record 42 of Set 9 | sinyavskoye
# Processing Record 43 of Set 9 | innisfail
# Processing Record 44 of Set 9 | micheweni
# Processing Record 45 of Set 9 | champerico
# Processing Record 46 of Set 9 | kirovskiy
# Processing Record 47 of Set 9 | acapulco
# Processing Record 48 of Set 9 | zalesovo
# Processing Record 49 of Set 9 | novaya igirma
# Processing Record 50 of Set 9 | kharan
# Processing Record 1 of Set 10 | ilulissat
# Processing Record 2 of Set 10 | warqla
# City warqla not found. Skipping...
# Processing Record 3 of Set 10 | kralendijk
# Processing Record 4 of Set 10 | cayenne
# Processing Record 5 of Set 10 | el mahalla el kubra
# City el mahalla el kubra not found. Skipping...
# Processing Record 6 of Set 10 | waiuku
# Processing Record 7 of Set 10 | agaro
# Processing Record 8 of Set 10 | vardo
# Processing Record 9 of Set 10 | ardistan
# City ardistan not found. Skipping...
# Processing Record 10 of Set 10 | biryusinsk
# Processing Record 11 of Set 10 | yumen
# Processing Record 12 of Set 10 | mount gambier
# Processing Record 13 of Set 10 | moron
# Processing Record 14 of Set 10 | benguela
# Processing Record 15 of Set 10 | mykhaylivka
# Processing Record 16 of Set 10 | tautira
# Processing Record 17 of Set 10 | san jeronimo
# Processing Record 18 of Set 10 | roald
# Processing Record 19 of Set 10 | tianpeng
# Processing Record 20 of Set 10 | carnarvon
# Processing Record 21 of Set 10 | powell river
# Processing Record 22 of Set 10 | fairlie
# Processing Record 23 of Set 10 | barcelos
# Processing Record 24 of Set 10 | aksarka
# Processing Record 25 of Set 10 | manali
# Processing Record 26 of Set 10 | kolobrzeg
# Processing Record 27 of Set 10 | raga
# Processing Record 28 of Set 10 | makushino
# Processing Record 29 of Set 10 | ewa beach
# Processing Record 30 of Set 10 | wahiawa
# Processing Record 31 of Set 10 | aksu
# Processing Record 32 of Set 10 | matagami
# Processing Record 33 of Set 10 | tarauaca
# Processing Record 34 of Set 10 | sunrise manor
# Processing Record 35 of Set 10 | medeiros neto
# Processing Record 36 of Set 10 | alekseyevsk
# Processing Record 37 of Set 10 | antofagasta
# Processing Record 38 of Set 10 | pimentel
# Processing Record 39 of Set 10 | cabedelo
# Processing Record 40 of Set 10 | bull savanna
# Processing Record 41 of Set 10 | manta
# Processing Record 42 of Set 10 | walvis bay
# Processing Record 43 of Set 10 | albino
# Processing Record 44 of Set 10 | kavaratti
# Processing Record 45 of Set 10 | anadyr
# Processing Record 46 of Set 10 | sanislau
# Processing Record 47 of Set 10 | kavieng
# Processing Record 48 of Set 10 | santa luzia
# Processing Record 49 of Set 10 | linhares
# Processing Record 50 of Set 10 | da nang
# Processing Record 1 of Set 11 | omboue
# Processing Record 2 of Set 11 | nantucket
# Processing Record 3 of Set 11 | lyngdal
# Processing Record 4 of Set 11 | port moresby
# Processing Record 5 of Set 11 | jiaojiang
# Processing Record 6 of Set 11 | eldorado
# Processing Record 7 of Set 11 | nadym
# Processing Record 8 of Set 11 | matara
# Processing Record 9 of Set 11 | cordoba
# Processing Record 10 of Set 11 | umm lajj
# Processing Record 11 of Set 11 | harper
# Processing Record 12 of Set 11 | meulaboh
# Processing Record 13 of Set 11 | kununurra
# Processing Record 14 of Set 11 | flin flon
# Processing Record 15 of Set 11 | san vicente
# Processing Record 16 of Set 11 | sabha
# Processing Record 17 of Set 11 | parabel
# Processing Record 18 of Set 11 | cao bang
# Processing Record 19 of Set 11 | sioux lookout
# Processing Record 20 of Set 11 | gairo
# Processing Record 21 of Set 11 | porosozero
# Processing Record 22 of Set 11 | alice springs
# Processing Record 23 of Set 11 | mugur-aksy
# Processing Record 24 of Set 11 | egvekinot
# Processing Record 25 of Set 11 | kalulushi
# Processing Record 26 of Set 11 | mount isa
# Processing Record 27 of Set 11 | sarkand
# Processing Record 28 of Set 11 | suez
# Processing Record 29 of Set 11 | malanje
# Processing Record 30 of Set 11 | nara
# Processing Record 31 of Set 11 | abha
# Processing Record 32 of Set 11 | arriana
# Processing Record 33 of Set 11 | pokhara
# Processing Record 34 of Set 11 | bima
# Processing Record 35 of Set 11 | oxbow
# Processing Record 36 of Set 11 | dunkwa
# Processing Record 37 of Set 11 | barajevo
# Processing Record 38 of Set 11 | tungor
# Processing Record 39 of Set 11 | svetlyy
# Processing Record 40 of Set 11 | marathon
# Processing Record 41 of Set 11 | kenai
# Processing Record 42 of Set 11 | santa cruz de tenerife
# Processing Record 43 of Set 11 | muscatine
# Processing Record 44 of Set 11 | nouakchott
# Processing Record 45 of Set 11 | college
# Processing Record 46 of Set 11 | abay
# Processing Record 47 of Set 11 | waipawa
# Processing Record 48 of Set 11 | bay roberts
# Processing Record 49 of Set 11 | celestun
# Processing Record 50 of Set 11 | seoul
# Processing Record 1 of Set 12 | hervey bay
# Processing Record 2 of Set 12 | the pas
# Processing Record 3 of Set 12 | sola
# Processing Record 4 of Set 12 | maceio
# Processing Record 5 of Set 12 | sumbawa
# City sumbawa not found. Skipping...
# Processing Record 6 of Set 12 | dedovichi
# Processing Record 7 of Set 12 | gondanglegi
# Processing Record 8 of Set 12 | fairbanks
# Processing Record 9 of Set 12 | pitimbu
# Processing Record 10 of Set 12 | sayyan
# Processing Record 11 of Set 12 | kaka
# Processing Record 12 of Set 12 | awash
# Processing Record 13 of Set 12 | berck
# Processing Record 14 of Set 12 | saint-pierre
# Processing Record 15 of Set 12 | kortkeros
# Processing Record 16 of Set 12 | jinxiang
# Processing Record 17 of Set 12 | atchison
# Processing Record 18 of Set 12 | poronaysk
# Processing Record 19 of Set 12 | melito di porto salvo
# Processing Record 20 of Set 12 | honiara
# Processing Record 21 of Set 12 | somerset west
# Processing Record 22 of Set 12 | grand centre
# City grand centre not found. Skipping...
# Processing Record 23 of Set 12 | turbiv
# Processing Record 24 of Set 12 | bretcu
# Processing Record 25 of Set 12 | malwan
# City malwan not found. Skipping...
# Processing Record 26 of Set 12 | oistins
# Processing Record 27 of Set 12 | morondava
# Processing Record 28 of Set 12 | latung
# Processing Record 29 of Set 12 | bonthe
# Processing Record 30 of Set 12 | mokhsogollokh
# Processing Record 31 of Set 12 | kulhudhuffushi
# Processing Record 32 of Set 12 | hojai
# Processing Record 33 of Set 12 | vakhrushev
# Processing Record 34 of Set 12 | arlit
# Processing Record 35 of Set 12 | yenagoa
# Processing Record 36 of Set 12 | mareeba
# Processing Record 37 of Set 12 | road town
# Processing Record 38 of Set 12 | diphu
# Processing Record 39 of Set 12 | kharod
# Processing Record 40 of Set 12 | marsh harbour
# Processing Record 41 of Set 12 | sambava
# Processing Record 42 of Set 12 | spassk
# Processing Record 43 of Set 12 | den helder
# Processing Record 44 of Set 12 | baykit
# Processing Record 45 of Set 12 | casa grande
# Processing Record 46 of Set 12 | wukari
# Processing Record 47 of Set 12 | saleaula
# City saleaula not found. Skipping...
# Processing Record 48 of Set 12 | piacabucu
# Processing Record 49 of Set 12 | zonguldak
# Processing Record 50 of Set 12 | biak
# Processing Record 1 of Set 13 | wilmington island
# Processing Record 2 of Set 13 | altay
# Processing Record 3 of Set 13 | ginir
# Processing Record 4 of Set 13 | vila velha
# Processing Record 5 of Set 13 | grajau
# Processing Record 6 of Set 13 | constantine
# Processing Record 7 of Set 13 | la asuncion
# Processing Record 8 of Set 13 | hajipur
# Processing Record 9 of Set 13 | manavalakurichi
# Processing Record 10 of Set 13 | havoysund
# Processing Record 11 of Set 13 | nalut
# Processing Record 12 of Set 13 | la ronge
# Processing Record 13 of Set 13 | brzeg dolny
# Processing Record 14 of Set 13 | paamiut
# Processing Record 15 of Set 13 | anaconda
# Processing Record 16 of Set 13 | northam
# Processing Record 17 of Set 13 | uyskoye
# Processing Record 18 of Set 13 | kano
# Processing Record 19 of Set 13 | iqaluit
# Processing Record 20 of Set 13 | chegdomyn
# Processing Record 21 of Set 13 | bolshevik
# Processing Record 22 of Set 13 | lagoa
# Processing Record 23 of Set 13 | horsham
# Processing Record 24 of Set 13 | washington
# Processing Record 25 of Set 13 | valea ciorii
# Processing Record 26 of Set 13 | krasnoye
# Processing Record 27 of Set 13 | san juan
# Processing Record 28 of Set 13 | barra patuca
# Processing Record 29 of Set 13 | yarada
# Processing Record 30 of Set 13 | mandalgovi
# Processing Record 31 of Set 13 | poum
# Processing Record 32 of Set 13 | khovu-aksy
# Processing Record 33 of Set 13 | xiongyue
# Processing Record 34 of Set 13 | bagalkot
# Processing Record 35 of Set 13 | boyolangu
# Processing Record 36 of Set 13 | ambanja
# Processing Record 37 of Set 13 | karpathos
# Processing Record 38 of Set 13 | bistret
# Processing Record 39 of Set 13 | husavik
# Processing Record 40 of Set 13 | seymchan
# Processing Record 41 of Set 13 | labuhan
# Processing Record 42 of Set 13 | yulara
# Processing Record 43 of Set 13 | aguimes
# Processing Record 44 of Set 13 | douentza
# Processing Record 45 of Set 13 | baruun-urt
# Processing Record 46 of Set 13 | dongsheng
# Processing Record 47 of Set 13 | hofn
# Processing Record 48 of Set 13 | bayshore gardens
# Processing Record 49 of Set 13 | port macquarie
# Processing Record 50 of Set 13 | hirara
# Processing Record 1 of Set 14 | la rioja
# Processing Record 2 of Set 14 | khandbari
# Processing Record 3 of Set 14 | miri
# Processing Record 4 of Set 14 | hambantota
# Processing Record 5 of Set 14 | hope
# Processing Record 6 of Set 14 | acari
# Processing Record 7 of Set 14 | asau
# Processing Record 8 of Set 14 | strezhevoy
# Processing Record 9 of Set 14 | pangnirtung
# Processing Record 10 of Set 14 | priiskovyy
# Processing Record 11 of Set 14 | wajir
# Processing Record 12 of Set 14 | zverinogolovskoye
# Processing Record 13 of Set 14 | jibuti
# Processing Record 14 of Set 14 | kousseri
# Processing Record 15 of Set 14 | aleksandrov gay
# Processing Record 16 of Set 14 | ouadda
# Processing Record 17 of Set 14 | sao goncalo do amarante
# Processing Record 18 of Set 14 | sackville
# Processing Record 19 of Set 14 | mrirt
# City mrirt not found. Skipping...
# Processing Record 20 of Set 14 | ternate
# Processing Record 21 of Set 14 | nagina
# Processing Record 22 of Set 14 | bedford
# Processing Record 23 of Set 14 | colares
# Processing Record 24 of Set 14 | berlin
# Processing Record 25 of Set 14 | byron bay
# Processing Record 26 of Set 14 | leh
# Processing Record 27 of Set 14 | we
# City we not found. Skipping...
# Processing Record 28 of Set 14 | kanbe
# Processing Record 29 of Set 14 | ustka
# Processing Record 30 of Set 14 | ibra
# Processing Record 31 of Set 14 | sinnamary
# Processing Record 32 of Set 14 | kruisfontein
# Processing Record 33 of Set 14 | wajima
# Processing Record 34 of Set 14 | san rafael
# Processing Record 35 of Set 14 | suzun
# Processing Record 36 of Set 14 | awjilah
# Processing Record 37 of Set 14 | isangel
# Processing Record 38 of Set 14 | marcona
# City marcona not found. Skipping...
# Processing Record 39 of Set 14 | deputatskiy
# Processing Record 40 of Set 14 | namibe
# Processing Record 41 of Set 14 | augusto correa
# Processing Record 42 of Set 14 | sobolevo
# Processing Record 43 of Set 14 | methoni
# Processing Record 44 of Set 14 | olinda
# Processing Record 45 of Set 14 | north bend
# Processing Record 46 of Set 14 | valle de allende
# Processing Record 47 of Set 14 | tigre
# Processing Record 48 of Set 14 | polyarnyy
# Processing Record 49 of Set 14 | yarim
# Processing Record 50 of Set 14 | atar
# Processing Record 1 of Set 15 | noumea
# Processing Record 2 of Set 15 | talara
# Processing Record 3 of Set 15 | bonito
# Processing Record 4 of Set 15 | kuche
# City kuche not found. Skipping...
# Processing Record 5 of Set 15 | jahrom
# City jahrom not found. Skipping...
# Processing Record 6 of Set 15 | eskisehir
# Processing Record 7 of Set 15 | pacifica
# Processing Record 8 of Set 15 | atambua
# Processing Record 9 of Set 15 | lompoc
# Processing Record 10 of Set 15 | naze
# Processing Record 11 of Set 15 | belmonte
# Processing Record 12 of Set 15 | babanusah
# City babanusah not found. Skipping...
# Processing Record 13 of Set 15 | jiuquan
# Processing Record 14 of Set 15 | saint stephen
# Processing Record 15 of Set 15 | caravelas
# Processing Record 16 of Set 15 | guatire
# Processing Record 17 of Set 15 | tidore
# City tidore not found. Skipping...
# Processing Record 18 of Set 15 | abu dhabi
# Processing Record 19 of Set 15 | altamira
# Processing Record 20 of Set 15 | marawi
# Processing Record 21 of Set 15 | antigonish
# Processing Record 22 of Set 15 | sawakin
# Processing Record 23 of Set 15 | haines junction
# Processing Record 24 of Set 15 | moerai
# Processing Record 25 of Set 15 | mahanje
# Processing Record 26 of Set 15 | dafeng
# Processing Record 27 of Set 15 | sirjan
# Processing Record 28 of Set 15 | binay
# Processing Record 29 of Set 15 | gambiran
# Processing Record 30 of Set 15 | ionia
# Processing Record 31 of Set 15 | somerset
# Processing Record 32 of Set 15 | axim
# Processing Record 33 of Set 15 | zlitan
# Processing Record 34 of Set 15 | bar harbor
# Processing Record 35 of Set 15 | valparaiso
# Processing Record 36 of Set 15 | punta alta
# Processing Record 37 of Set 15 | karamea
# City karamea not found. Skipping...
# Processing Record 38 of Set 15 | mahadday weyne
# City mahadday weyne not found. Skipping...
# Processing Record 39 of Set 15 | prince rupert
# Processing Record 40 of Set 15 | asuncion
# Processing Record 41 of Set 15 | gizo
# Processing Record 42 of Set 15 | hay river
# Processing Record 43 of Set 15 | basco
# Processing Record 44 of Set 15 | ilave
# Processing Record 45 of Set 15 | qaqortoq
# Processing Record 46 of Set 15 | korgen
# Processing Record 47 of Set 15 | dangriga
# Processing Record 48 of Set 15 | whitianga
# Processing Record 49 of Set 15 | mongo
# Processing Record 50 of Set 15 | shellbrook
# Processing Record 1 of Set 16 | xinyu
# Processing Record 2 of Set 16 | chiang klang
# Processing Record 3 of Set 16 | ambulu
# Processing Record 4 of Set 16 | kobojango
# City kobojango not found. Skipping...
# Processing Record 5 of Set 16 | necochea
# Processing Record 6 of Set 16 | itaituba
# Processing Record 7 of Set 16 | acton
# Processing Record 8 of Set 16 | ust-kut
# Processing Record 9 of Set 16 | loreto
# Processing Record 10 of Set 16 | ishigaki
# Processing Record 11 of Set 16 | buala
# Processing Record 12 of Set 16 | christchurch
# Processing Record 13 of Set 16 | sanming
# Processing Record 14 of Set 16 | sungaipenuh
# Processing Record 15 of Set 16 | inta
# Processing Record 16 of Set 16 | cockburn town
# Processing Record 17 of Set 16 | haimen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
# Conver the array of dictionaries to a PD Df
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Port Alfred      ZA -33.5906   26.8910     57.18        89          40
# 1         Saldanha      ZA -33.0117   17.9442     50.05        81           0
# 2       Sao Filipe      CV  14.8961  -24.4956     73.74        71           7
# 3             Lamu      KE  -2.2717   40.9020     80.82        82          24
# 4         Longonjo      AO -12.9067   15.2533     63.88        70          94
# ..             ...     ...      ...       ...       ...       ...         ...
# 701        Sanming      CN  26.2486  117.6186     80.35        82          56
# 702    Sungaipenuh      ID  -2.0833  101.3833     70.68        78          98
# 703           Inta      RU  66.0317   60.1659     37.36        95         100
# 704  Cockburn Town      TC  21.4612  -71.1419     76.68        69           0
# 705         Haimen      CN  23.1935  116.6142     84.09        67           1
#
#      Wind Speed Current Description
# 0          1.01    scattered clouds
# 1         11.52           clear sky
# 2         16.49           clear sky
# 3         10.20          light rain
# 4          3.27     overcast clouds
# ..          ...                 ...
# 701        0.65       moderate rain
# 702        1.28     overcast clouds
# 703       19.48     overcast clouds
# 704       18.16           clear sky
# 705        6.69           clear sky
#
# [706 rows x 9 columns]

# %%
#create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"

#Export the cityDaty into CSV
city_data_df.to_csv(output_data_file, index_label = "City_ID")
